# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data,clusters=make_blobs(n_samples=100,centers=5)

# %%
data
# Out:
# array([[  4.4120019 ,   8.9971846 ],
#        [ -7.90960927,  -2.48934006],
#        [ -9.16872793,  -1.29620543],
#        [  1.98175954,   7.96743437],
#        [  2.35838631,   0.88756353],
#        [ -8.82277689,  -2.94411519],
#        [  4.27669563,   9.8062042 ],
#        [ -8.67805758,  -2.19315146],
#        [ -7.62154179,  -1.57745227],
#        [ -9.15919613,  -3.07080823],
#        [  2.85234726,  10.00602057],
#        [ -6.31671056,  -1.0659916 ],
#        [ -8.96994188,  -1.93125841],
#        [  4.18090719,   8.47302262],
#        [ -0.86395788,  -0.74571103],
#        [ -9.57593837,  -1.58958214],
#        [ -0.04232459,   0.59478381],
#        [  2.36579164,  10.02006431],
#        [ -9.29738215,  -2.87553429],
#        [ -8.17933583,  -4.26415559],
#        [  3.08184545,   9.51293823],
#        [  2.16366577,   8.6257337 ],
#        [  2.7871577 ,   8.59424556],
#        [  1.93709596,   0.13773834],
#        [  3.38700979,   8.99466431],
#        [ -9.13089235,  -1.07113688],
#        [-11.6920922 ,  -1.83122235],
#        [ -8.0747539 ,  -0.47926722],
#        [  1.72495813,  10.03792469],
#        [ -8.39381317,  -2.88457187],
#        [ -0.07843172,   1.27104468],
#        [  1.60006564,  -0.89536399],
#        [  3.47042845,   8.58894101],
#        [ -1.91359197,   0.49246434],
#        [  1.27954045,   2.3707212 ],
#        [  2.42352946,  10.57890903],
#        [  0.82630554,  -2.20149225],
#        [  2.07872717,   9.03564435],
#        [  4.19060041,   7.01900418],
#        [  1.70952311,   1.22760046],
#        [ -0.55189048,  -0.45230953],
#        [  0.59098116,   1.91926758],
#        [  4.63557268,   8.93890652],
#        [-10.1532024 ,  -1.5797932 ],
#        [ -9.52281623,  -2.23492117],
#        [  4.20204955,  10.78874608],
#        [  1.44228091,   0.56435227],
#        [  1.66722765,   7.0042951 ],
#        [  3.24004758,   8.67540374],
#        [  2.4798583 ,   8.18315816],
#        [ -1.33565226,  -0.09168304],
#        [ -9.0381297 ,  -1.63504944],
#        [ -9.26370087,  -1.39426814],
#        [  0.89002742,   0.48166039],
#        [ -8.60699734,  -1.67353452],
#        [ -8.81130161,  -1.34616876],
#        [  3.86582434,   8.2405338 ],
#        [  3.14261789,   9.26719113],
#        [  1.55992134,   9.95057238],
#        [  4.23573275,   9.10069112],
#        [-10.24060634,  -2.62291558],
#        [  3.02225365,   9.78411279],
#        [  2.27040369,   8.19774081],
#        [  3.12838541,   7.58254977],
#        [ -8.44626621,  -2.11761908],
#        [  3.16667336,  10.77723019],
#        [ -8.48201681,  -0.77728789],
#        [ -8.91456234,  -2.35772165],
#        [ -8.73256286,  -0.92393319],
#        [  0.05540965,   2.85264184],
#        [ -8.40351845,  -3.76998513],
#        [  0.42085599,   0.37489655],
#        [ -8.56391741,  -0.01571649],
#        [  2.08099884,   9.9266114 ],
#        [ -6.93872701,  -1.4841173 ],
#        [  3.24998595,   9.92939482],
#        [  3.29193295,   7.44495704],
#        [ -8.61345056,  -0.62212785],
#        [  1.97776659,   0.90915813],
#        [ -8.82919098,  -3.43377458],
#        [  1.3837268 ,   2.13083689],
#        [ -9.78955437,  -1.68496302],
#        [ -9.14505539,  -2.61096279],
#        [ -8.29754024,  -2.07604856],
#        [  3.2348516 ,   8.60987303],
#        [ -8.76319612,  -1.94067048],
#        [  2.9567245 ,   8.83446656],
#        [  2.79937671,   8.99979574],
#        [  2.37419201,   9.25811095],
#        [  1.57107146,   7.38547426],
#        [  2.59367554,   8.84243846],
#        [ -0.16159553,   0.14651522],
#        [ -8.97988899,  -1.49028682],
#        [ -7.97576976,  -2.46490053],
#        [ -8.38460977,  -1.98414577],
#        [  1.77582442,   7.40994297],
#        [ -9.4455026 ,  -0.5059961 ],
#        [ -8.55994117,  -1.72823089],
#        [  4.89037793,   7.67259894],
#        [  3.21176701,  10.39974041]])

# %%
clusters
# Out:
# array([4, 1, 3, 2, 0, 1, 2, 3, 3, 3, 4, 3, 3, 2, 0, 3, 0, 4, 1, 1, 4, 2,
#        2, 0, 2, 3, 1, 3, 4, 3, 0, 0, 2, 0, 0, 4, 0, 4, 2, 0, 0, 0, 4, 1,
#        1, 4, 0, 4, 2, 2, 0, 1, 1, 0, 3, 1, 4, 4, 4, 4, 1, 2, 2, 2, 1, 4,
#        3, 3, 1, 0, 1, 0, 1, 4, 3, 2, 2, 3, 0, 1, 0, 3, 1, 3, 4, 3, 4, 2,
#        2, 2, 2, 0, 1, 1, 3, 4, 1, 3, 2, 4])

# %%
kmc=KMeans(n_clusters=5)

# %%
kmc.fit(data)
# Out:
# KMeans(n_clusters=5)

# %%
kmc.cluster_centers_
# Out:
# array([[ 3.13376743,  8.26596068],
#        [-8.79731989, -1.9009733 ],
#        [ 1.26219769,  1.15476844],
#        [ 2.80089714,  9.94246347],
#        [-0.4527314 , -0.23531699]])

# %%
clusters
# Out:
# array([4, 1, 3, 2, 0, 1, 2, 3, 3, 3, 4, 3, 3, 2, 0, 3, 0, 4, 1, 1, 4, 2,
#        2, 0, 2, 3, 1, 3, 4, 3, 0, 0, 2, 0, 0, 4, 0, 4, 2, 0, 0, 0, 4, 1,
#        1, 4, 0, 4, 2, 2, 0, 1, 1, 0, 3, 1, 4, 4, 4, 4, 1, 2, 2, 2, 1, 4,
#        3, 3, 1, 0, 1, 0, 1, 4, 3, 2, 2, 3, 0, 1, 0, 3, 1, 3, 4, 3, 4, 2,
#        2, 2, 2, 0, 1, 1, 3, 4, 1, 3, 2, 4])

# %%
plt.figure(figsize=(10,10))
plt.scatter(data[:,0],data[:,1],c=clusters)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.scatter(data[:,0],data[:,1],c=kmc.labels_)
plt.scatter(kmc.cluster_centers_[:,0],kmc.cluster_centers_[:,1],c="black",marker="")
plt.show()
